# %% [markdown]
# # Predicting Fraudulent Transactions Using Neural Networks
#
# Now that you’ve learned how to build a deep neural network, you’ll apply those skills to create a deep learning model that can predict financial fraud. But in this activity, rather than a regression deep learning model, you will create a classification deep learning model.
#
# ## Instructions:
#
# ### Load and Preprocess the Data
#
# 1. Read the data from the CSV file into a Pandas DataFrame.
#
# 2. Create the target set `y` by assigning the values of the “isFraud” column of the DataFrame.
#
# 3. Define the features set `X` by including all of the columns of the DataFrame except for the “isFraud” column.
#
# 4. Create the training and testing sets using the `train_test_split` function from scikit-learn.
#
# 5. Scale the features data using the `StandardScaler` from scikit-learn.
#
# ### Create and Evaluate a Deep Neural Network Model
#
# 1. Create a deep neural network model with the following structure:
#
#     * 9 inputs
#     * First hidden layer with 18 neurons
#     * Second hidden layer with 8 neurons
#     * Output layer with a single output
#     * Hidden layers use the ReLU activation function, and output layer uses the sigmoid activation function
#
# 2. Display the model structure using the 'summary` function.
#
# 3. Compile the neural network model using the `binary_crossentropy` loss function, the `adam` optimizer, and `accuracy` as an additional metric.
#
# 4. Fit the model with the training data, using 100 epochs.
#
# 5. Evaluate the model using testing data and the `evaluate` method.
#
#
# ## References:
#
# [Keras Sequential model](https://keras.io/api/models/sequential/)
#
# [Keras Dense module](https://keras.io/api/layers/core_layers/dense/)
#
# [Keras evaluate](https://keras.io/api/models/model_training_apis/)

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load and Preprocess the Data

# %% [markdown]
# ### Step 1: Read the data from the CSV file into a Pandas DataFrame.

# %%
# Upload credit_card_transactions.csv to Colab
from google.colab import files

csv_file = files.upload()
# Out:
#      <input type="file" id="files-283aa1f9-f941-4c6c-9a58-f7119de6ddf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-283aa1f9-f941-4c6c-9a58-f7119de6ddf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving credit_card_transactions.csv to credit_card_transactions.csv

# %%
# Read the credit_card_transactions.csv file from the Resources folder into a Pandas DataFrame
cc_transactions_df = pd.read_csv("credit_card_transactions.csv")

# Review the DataFrame
cc_transactions_df.head()
# Out:
#    dateMonth  dateWeekday  dateQuarter  ...  oldbalanceDest  newbalanceDest  isFraud
# 0          1            1            1  ...            0.00            0.00        0
# 1          1            1            1  ...       518041.64      1305828.01        0
# 2          1            1            1  ...        10089.00      1157398.83        0
# 3          1            1            1  ...       880045.33       206147.08        0
# 4          1            1            1  ...            0.00            0.00        0
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Step 2: Create the target set `y` by assigning the values of the “isFraud” column of the DataFrame.

# %%
# Define the target set by selecting the isFraud column
y = cc_transactions_df["isFraud"]

# Display a sample of y
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: isFraud, dtype: int64

# %% [markdown]
# ### Step 3: Define the features set `X` by including all of the columns of the DataFrame except for the “isFraud” column.

# %%
# Define features set X by selecting all columns but the isFraud
X = cc_transactions_df.drop(columns=["isFraud"])

# Display the features DataFrame
X.head()
# Out:
#    dateMonth  dateWeekday  ...  oldbalanceDest  newbalanceDest
# 0          1            1  ...            0.00            0.00
# 1          1            1  ...       518041.64      1305828.01
# 2          1            1  ...        10089.00      1157398.83
# 3          1            1  ...       880045.33       206147.08
# 4          1            1  ...            0.00            0.00
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Step 4: Create the training and testing sets using the `train_test_split` function from scikit-learn.

# %%
# Create training and testing datasets using train_teat_split
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 5:  Scale the features data using the `StandardScaler` from scikit-learn.

# %%
# Create the StandardScaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler to the features training dataset
X_scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Scale both the training and testing data from the features dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Create and Evaluate a Deep Neural Network Model

# %% [markdown]
# ### Step 1: Create a deep neural network model with the following structure:
#
#     * 9 inputs
#     * First hidden layer with 18 neurons
#     * Second hidden layer with 8 neurons
#     * Output layer with a single output
#     * Hidden layers use the ReLU activation function, and output layer uses the sigmoid activation function

# %%
# Define the the number of inputs to the model
number_inputs = 9

# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 18

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 8

# Create the Sequential model instance
nn = Sequential()

# Add the first Dense layer specifying the number of inputs, the number of hidden nodes, and the activation function
nn.add(Dense(units=hidden_nodes_layer1, input_dim=number_inputs, activation="relu"))

# Add the second Dense layer specifying the number of hidden nodes and the activation function
nn.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(Dense(1, activation="sigmoid"))

# %% [markdown]
# ### Step 2. Display the model structure using the `summary` function.

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 18)                180
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 152
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 341
# Trainable params: 341
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Step 3: Compile the neural network model using the `binary_crossentropy` loss function, the `adam` optimizer, and `accuracy` as an additional metric.

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### Step 4: Fit the model with the training data, using 100 epochs.

# %%
# Fit the model using 100 epochs and the training data
model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.0534 - accuracy: 0.9853
# Epoch 2/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0094 - accuracy: 0.9988
# Epoch 3/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0089 - accuracy: 0.9988
# Epoch 4/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0085 - accuracy: 0.9989
# Epoch 5/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0082 - accuracy: 0.9989
# Epoch 6/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0080 - accuracy: 0.9989
# Epoch 7/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0077 - accuracy: 0.9989
# Epoch 8/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0074 - accuracy: 0.9989
# Epoch 9/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0071 - accuracy: 0.9989
# Epoch 10/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0069 - accuracy: 0.9989
# Epoch 11/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0066 - accuracy: 0.9989
# Epoch 12/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0064 - accuracy: 0.9990
# Epoch 13/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0063 - accuracy: 0.9989
# Epoch 14/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0062 - accuracy: 0.9989
# Epoch 15/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0062 - accuracy: 0.9989
# Epoch 16/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0060 - accuracy: 0.9990
# Epoch 17/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0059 - accuracy: 0.9990
# Epoch 18/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0058 - accuracy: 0.9990
# Epoch 19/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0058 - accuracy: 0.9990
# Epoch 20/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0058 - accuracy: 0.9990
# Epoch 21/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0056 - accuracy: 0.9990
# Epoch 22/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0056 - accuracy: 0.9990
# Epoch 23/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0056 - accuracy: 0.9989
# Epoch 24/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0056 - accuracy: 0.9990
# Epoch 25/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0054 - accuracy: 0.9990
# Epoch 26/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0055 - accuracy: 0.9990
# Epoch 27/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0055 - accuracy: 0.9990
# Epoch 28/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0054 - accuracy: 0.9990
# Epoch 29/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 30/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0053 - accuracy: 0.9989
# Epoch 31/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0053 - accuracy: 0.9989
# Epoch 32/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 33/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 34/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 35/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 36/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 37/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 38/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 39/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 40/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 41/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0050 - accuracy: 0.9991
# Epoch 42/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 43/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 44/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 45/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 46/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 47/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 48/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 49/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0050 - accuracy: 0.9989
# Epoch 50/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 51/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 52/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 53/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 54/100
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 55/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 56/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 57/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 58/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 59/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 60/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9991
# Epoch 61/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 62/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 63/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9989
# Epoch 64/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 65/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 66/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 67/100
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 68/100
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 69/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9989
# Epoch 70/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9991
# Epoch 71/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 72/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 73/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 74/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 75/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 76/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 77/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 78/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 79/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 80/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 81/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 82/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 83/100
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 84/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 85/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 86/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0047 - accuracy: 0.9991
# Epoch 87/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 88/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 89/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 90/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 91/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 92/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 93/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 94/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 95/100
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 96/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 97/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 98/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 99/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 100/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0045 - accuracy: 0.9991

# %% [markdown]
# ### Step 5: Evaluate the model using testing data and the `evaluate` method.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)

# Display the evaluation results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 782/782 - 1s - loss: 0.0062 - accuracy: 0.9988
# Loss: 0.006215384695678949, Accuracy: 0.9988399744033813
